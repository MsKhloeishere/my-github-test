# %% [markdown]
# Group 3- Week 9 Peer Programming Project

# %%
import pandas as pd

# %%
nyc_violations_df = pd.read_csv('nyc-parking-violations-2020.csv', usecols=['Plate ID', 'Registration State', 'Vehicle Make', 'Vehicle Color', 'Violation Time', 'Street Name'])

nyc_violations_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12495734 entries, 0 to 12495733
# Data columns (total 6 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Plate ID            object
#  1   Registration State  object
#  2   Vehicle Make        object
#  3   Violation Time      object
#  4   Street Name         object
#  5   Vehicle Color       object
# dtypes: object(6)
# memory usage: 572.0+ MB

# %%
nyc_violations_df
# Out:
#           Plate ID Registration State Vehicle Make Violation Time  \
# 0           J58JKX                 NJ        HONDA          0523P
# 1          KRE6058                 PA        ME/BE          0428P
# 2          444326R                 NJ        LEXUS          0625A
# 3          F728330                 OH        CHEVR          1106A
# 4          FMY9090                 NY         JEEP          1253A
# ...            ...                ...          ...            ...
# 12495729   62161MM                 NY         FORD          1111A
# 12495730   GYE7330                 NY        HONDA          0444P
# 12495731   HNY4802                 NY         FORD          0210A
# 12495732  T687081C                 NY        TOYOT          0225P
# 12495733    3497ZN                 WA        UTILI          0456A
#
#                Street Name Vehicle Color
# 0                    43 ST            BK
# 1                 UNION ST           BLK
# 2          CLERMONT AVENUE         BLACK
# 3             DIVISION AVE           NaN
# 4                 GRAND ST          GREY
# ...                    ...           ...
# 12495729           3RD AVE            BR
# 12495730    PELHAM PARK DR           BLK
# 12495731         LYDIG AVE            GY
# 12495732       E 68 STREET           BLK
# 12495733  W/S/O 182 STREET         WHITE
#
# [12495734 rows x 6 columns]

# %% [markdown]
# Using the same nyc-ticket-violation dataset, let’s assume that tickets can be dismissed if the license plate, state, and/or street name are all there but without requiring the make of car. Remove rows that are missing one or more of these. How many rows remain? Assuming $100/ticket, how much money would the city lose as a result of this?

# %%
#Create New Data with deleted cells

new_violations_df=nyc_violations_df.dropna(subset=['Plate ID','Registration State','Street Name'])

# %%
new_violations_df
# Out:
#           Plate ID Registration State Vehicle Make Violation Time  \
# 0           J58JKX                 NJ        HONDA          0523P
# 1          KRE6058                 PA        ME/BE          0428P
# 2          444326R                 NJ        LEXUS          0625A
# 3          F728330                 OH        CHEVR          1106A
# 4          FMY9090                 NY         JEEP          1253A
# ...            ...                ...          ...            ...
# 12495729   62161MM                 NY         FORD          1111A
# 12495730   GYE7330                 NY        HONDA          0444P
# 12495731   HNY4802                 NY         FORD          0210A
# 12495732  T687081C                 NY        TOYOT          0225P
# 12495733    3497ZN                 WA        UTILI          0456A
#
#                Street Name Vehicle Color
# 0                    43 ST            BK
# 1                 UNION ST           BLK
# 2          CLERMONT AVENUE         BLACK
# 3             DIVISION AVE           NaN
# 4                 GRAND ST          GREY
# ...                    ...           ...
# 12495729           3RD AVE            BR
# 12495730    PELHAM PARK DR           BLK
# 12495731         LYDIG AVE            GY
# 12495732       E 68 STREET           BLK
# 12495733  W/S/O 182 STREET         WHITE
#
# [12494116 rows x 6 columns]

# %%
#Calculate deleted rows

del_rows=nyc_violations_df.shape[0]-new_violations_df.shape[0]

# %%
del_rows
# Out:
# 1618

# %%
#Calculate lost revenue

print(f"Money lost by New York due to misssing data is ${(del_rows*100):,.2f}")
# Out:
# Money lost by New York due to misssing data is $161,800.00
